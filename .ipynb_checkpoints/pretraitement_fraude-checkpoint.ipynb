# %%
# Importation des librairies
import pandas as pd
import numpy as np

# Fonction pour la numerisation des montants
def montant_clean(montant_raw):
    """
        Convertir le montant en float:
        Les montants du types:
            3, 4500, 05 USD en 34500.05
            34500.3k en 34500.3*1000
    """
    if pd.isna(montant_raw):
        return np.nan

    # Convertir en str et supprime les espaces vides
    montant_raw = str(montant_raw).strip()

    if 'k' in montant_raw.lower():
        montant_raw = montant_raw.replace(

# Chargements des donnees
df = pd.read_excel('dataset_pretraitement_fraude.xlsx')

# Visualisation des 
print(f"Le dataset a : {data.shape[0]} lignes x {data.shape[1]} colonnes")

# Les informations sur le dataset
print(df.columns)

print("\nApercu sur les donnees : ")
print(f"{df.head(5)}")

print("\n\nInformations sur les donnees : ")
print(df.info())

# Analyse sur les donnees
print(f"Le nombre de valeur manquantes : {df.isnull().sum()}")
# Out:
# Le dataset a : 618 lignes x 27 colonnes
# Index(['TransactionID', 'ClientID', 'DateTransaction_raw', 'Montant_raw',
#        'Devise_indiquee', 'Canal', 'Device', 'TypeMarchand', 'Ville_raw',
#        'Age', 'AncienneteCompte_raw', 'NbTrans_24h', 'RevenuMensuel_raw',
#        'Dette_raw', 'NiveauEtude', 'StatutMarital', 'Employe', 'Commentaire',
#        'Fraude', 'TODO_DateTransaction', 'TODO_JourSemaine',
#        'TODO_Montant_HTG', 'TODO_Anciennete_jours', 'TODO_Ville_norm',
#        'TODO_Age_clean', 'TODO_Revenu_clean', 'TODO_Dette_clean'],
#       dtype='object')
#
# Apercu sur les donnees :
#   TransactionID ClientID DateTransaction_raw   Montant_raw Devise_indiquee  \
# 0      TX100328    C1277          2025-12-03         50922             HTG
# 1      TX100500    C1161          2025-11-23        109468             HTG
# 2      TX100466    C1559          24/11/2025         34169             HTG
# 3      TX100439    C1854          17/10/2025  5,423.37 USD             HTG
# 4      TX100234    C1215          2026/01/17        825314             HTG
#
#     Canal   Device     TypeMarchand Ville_raw  Age  ... Commentaire  Fraude  \
# 0  Mobile  Unknown        Pharmacie    P-au-P   34  ...         NaN       0
# 1  Mobile      Web        Pharmacie    Hinche   44  ...         NaN       0
# 2     ATM  Android      Supermarché    JACMEL   17  ...         NaN       0
# 3     ATM      Web       Restaurant       HIN   23  ...         NaN       0
# 4     ATM      Web  Station-service  Gonaives   43  ...         NaN       0
#
#   TODO_DateTransaction  TODO_JourSemaine TODO_Montant_HTG  \
# 0                  NaN               NaN              NaN
# 1                  NaN               NaN              NaN
# 2                  NaN               NaN              NaN
# 3                  NaN               NaN              NaN
# 4                  NaN               NaN              NaN
#
#   TODO_Anciennete_jours TODO_Ville_norm TODO_Age_clean  TODO_Revenu_clean  \
# 0                   NaN             NaN            NaN                NaN
# 1                   NaN             NaN            NaN                NaN
# 2                   NaN             NaN            NaN                NaN
# 3                   NaN             NaN            NaN                NaN
# 4                   NaN             NaN            NaN                NaN
#
#    TODO_Dette_clean
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 27 columns]
#
#
# Informations sur les donnees :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TransactionID          618 non-null    object
#  1   ClientID               618 non-null    object
#  2   DateTransaction_raw    612 non-null    object
#  3   Montant_raw            596 non-null    object
#  4   Devise_indiquee        618 non-null    object
#  5   Canal                  618 non-null    object
#  6   Device                 618 non-null    object
#  7   TypeMarchand           618 non-null    object
#  8   Ville_raw              608 non-null    object
#  9   Age                    618 non-null    int64
#  10  AncienneteCompte_raw   618 non-null    object
#  11  NbTrans_24h            618 non-null    int64
#  12  RevenuMensuel_raw      573 non-null    object
#  13  Dette_raw              593 non-null    float64
#  14  NiveauEtude            559 non-null    object
#  15  StatutMarital          589 non-null    object
#  16  Employe                607 non-null    object
#  17  Commentaire            81 non-null     object
#  18  Fraude                 618 non-null    int64
#  19  TODO_DateTransaction   0 non-null      float64
#  20  TODO_JourSemaine       0 non-null      float64
#  21  TODO_Montant_HTG       0 non-null      float64
#  22  TODO_Anciennete_jours  0 non-null      float64
#  23  TODO_Ville_norm        0 non-null      float64
#  24  TODO_Age_clean         0 non-null      float64
#  25  TODO_Revenu_clean      0 non-null      float64
#  26  TODO_Dette_clean       0 non-null      float64
# dtypes: float64(9), int64(3), object(15)
# memory usage: 130.5+ KB
# None
# Le nombre de valeur manquantes : TransactionID              0
# ClientID                   0
# DateTransaction_raw        6
# Montant_raw               22
# Devise_indiquee            0
# Canal                      0
# Device                     0
# TypeMarchand               0
# Ville_raw                 10
# Age                        0
# AncienneteCompte_raw       0
# NbTrans_24h                0
# RevenuMensuel_raw         45
# Dette_raw                 25
# NiveauEtude               59
# StatutMarital             29
# Employe                   11
# Commentaire              537
# Fraude                     0
# TODO_DateTransaction     618
# TODO_JourSemaine         618
# TODO_Montant_HTG         618
# TODO_Anciennete_jours    618
# TODO_Ville_norm          618
# TODO_Age_clean           618
# TODO_Revenu_clean        618
# TODO_Dette_clean         618
# dtype: int64
